# %%
from src.chatbots.chatbot_graphs import base_chatbot
from langchain_core.messages import HumanMessage
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
base_chatbot()

# %%
chatbot = base_chatbot()

# %%
chatbot.invoke({"messages":[HumanMessage(content="HI")],"trace":[],"summary":None},config={"configurable":{"thread_id":"t-2","user_id":"vivek-1"}})
# Out:
# {'messages': [HumanMessage(content='HI', additional_kwargs={}, response_metadata={}, id='d4528924-f971-414e-823a-71c21871f94f'),
# ...

# %%
from langgraph.store.postgres import PostgresStore

# %%
ns = ("user", "vivekvro", "details")

# %%
with PostgresStore.from_conn_string("postgresql://postgres:postgres@localhost:5442/postgres") as store:
    store.setup()
    items = store.search(ns)
    existing_memory ="\n".join(it.value.get("data", "") for it in items)

# %%
existing_memory
# Out:
# ''
